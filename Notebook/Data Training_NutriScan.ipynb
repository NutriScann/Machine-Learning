# %% [markdown]
# ## **Import Library**

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers
from tensorflow.keras import Model
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import img_to_array, load_img
from mpl_toolkits.axes_grid1 import ImageGrid

# %%
print(tf. __version__)
# Out:
# 2.15.0

# %% [markdown]
# ## **Import Dataset**
# Dataset 1 : https://data.mendeley.com/datasets/vtjd68bmwt/1
#
# Dataset 2 : https://www.kaggle.com/datasets/kmader/food41

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data_path = '/content/drive/MyDrive/C241-PS121 Capstone Project /Indonesia_Food_Image'

TRAIN_DIR = '/content/drive/MyDrive/C241-PS121 Capstone Project /Indonesia_Food_Image/Training'
TEST_DIR = '/content/drive/MyDrive/C241-PS121 Capstone Project /Indonesia_Food_Image/Testing'
VAL_DIR = '/content/drive/MyDrive/C241-PS121 Capstone Project /Indonesia_Food_Image/Validation'

# BAKSO
TRAIN_BAKSO_DIR = os.path.join(TRAIN_DIR, "bakso/")
TEST_BAKSO_DIR = os.path.join(TEST_DIR, "bakso/")
VAL_BAKSO_DIR = os.path.join(VAL_DIR, "bakso/")

# BIBIMBAP
TRAIN_BIBIMBAP_DIR = os.path.join(TRAIN_DIR, "bibimbap/")
TEST_BIBIMBAP_DIR = os.path.join(TEST_DIR, "bibimbap/")
VAL_BIBIMBAP_DIR = os.path.join(VAL_DIR, "bibimbap/")

# BURGER
TRAIN_BURGER_DIR = os.path.join(TRAIN_DIR, "burger/")
TEST_BURGER_DIR = os.path.join(TEST_DIR, "burger/")
VAL_BURGER_DIR = os.path.join(VAL_DIR, "burger/")

# DONAT
TRAIN_DONAT_DIR = os.path.join(TRAIN_DIR, "donat/")
TEST_DONAT_DIR = os.path.join(TEST_DIR, "donat/")
VAL_DONAT_DIR = os.path.join(VAL_DIR, "donat/")

# ESKRIM
TRAIN_ESKRIM_DIR = os.path.join(TRAIN_DIR, "eskrim/")
TEST_ESKRIM_DIR = os.path.join(TEST_DIR, "eskrim/")
VAL_ESKRIM_DIR = os.path.join(VAL_DIR, "eskrim/")

# GADO GADO
TRAIN_GADO_DIR = os.path.join(TRAIN_DIR, "gado/")
TEST_GADO_DIR = os.path.join(TEST_DIR, "gado/")
VAL_GADO_DIR = os.path.join(VAL_DIR, "gado/")

# KENTANG GORENG
TRAIN_KENTANGGORENG_DIR = os.path.join(TRAIN_DIR, "kentang goreng/")
TEST_KENTANGGORENG_DIR = os.path.join(TEST_DIR, "kentang goreng/")
VAL_KENTANGGORENG_DIR = os.path.join(VAL_DIR, "kentang goreng/")

# NASI GORENG
TRAIN_NASGOR_DIR = os.path.join(TRAIN_DIR, "nasi goreng/")
TEST_NASGOR_DIR = os.path.join(TEST_DIR, "nasi goreng/")
VAL_NASGOR_DIR = os.path.join(VAL_DIR, "nasi goreng/")

# PANGSIT
TRAIN_PANGSIT_DIR = os.path.join(TRAIN_DIR, "pangsit/")
TEST_PANGSIT_DIR = os.path.join(TEST_DIR, "pangsit/")
VAL_PANGSIT_DIR = os.path.join(VAL_DIR, "pangsit/")

# PIZZA
TRAIN_PIZZA_DIR = os.path.join(TRAIN_DIR, "pizza/")
TEST_PIZZA_DIR = os.path.join(TEST_DIR, "pizza/")
VAL_PIZZA_DIR = os.path.join(VAL_DIR, "pizza/")

# RAMEN
TRAIN_RAMEN_DIR = os.path.join(TRAIN_DIR, "ramen/")
TEST_RAMEN_DIR = os.path.join(TEST_DIR, "ramen/")
VAL_RAMEN_DIR = os.path.join(VAL_DIR, "ramen/")

# RAWON
TRAIN_RAWON_DIR = os.path.join(TRAIN_DIR, "rawon/")
TEST_RAWON_DIR = os.path.join(TEST_DIR, "rawon/")
VAL_RAWON_DIR = os.path.join(VAL_DIR, "rawon/")

# RENDANG
TRAIN_RENDANG_DIR = os.path.join(TRAIN_DIR, "rendang/")
TEST_RENDANG_DIR = os.path.join(TEST_DIR, "rendang/")
VAL_RENDANG_DIR = os.path.join(VAL_DIR, "rendang/")

# SATE
TRAIN_SATE_DIR = os.path.join(TRAIN_DIR, "sate/")
TEST_SATE_DIR = os.path.join(TEST_DIR, "sate/")
VAL_SATE_DIR = os.path.join(VAL_DIR, "sate/")

# SOTO
TRAIN_SOTO_DIR = os.path.join(TRAIN_DIR, "soto/")
TEST_SOTO_DIR = os.path.join(TEST_DIR, "soto/")
VAL_SOTO_DIR = os.path.join(VAL_DIR, "soto/")

# %%
# Number of images in training directory
FOOD_CATEGORIES = ['bakso', 'bibimbap', 'burger', 'donat', 'eskrim', 'gado', 'kentang goreng', 'nasi goreng', 'pangsit', 'pizza','ramen','rawon', 'rendang', 'sate', 'soto']
for category in FOOD_CATEGORIES:
    print('There are {} {} images for training'.format(category, len(os.listdir(os.path.join(TRAIN_DIR, category)))))
# Out:
# There are bakso 700 images for training
# There are bibimbap 700 images for training
# There are burger 700 images for training
# There are donat 700 images for training
# There are eskrim 700 images for training
# There are gado 700 images for training
# There are kentang goreng 700 images for training
# There are nasi goreng 700 images for training
# There are pangsit 700 images for training
# There are pizza 700 images for training
# There are ramen 700 images for training
# There are rawon 700 images for training
# There are rendang 700 images for training
# There are sate 700 images for training
# There are soto 700 images for training

# %%
# Number of images in testing directory
for category in FOOD_CATEGORIES:
    print('There are {} {} images for testing'.format(category, len(os.listdir(os.path.join(TEST_DIR, category)))))
# Out:
# There are bakso 150 images for testing
# There are bibimbap 150 images for testing
# There are burger 150 images for testing
# There are donat 150 images for testing
# There are eskrim 150 images for testing
# There are gado 150 images for testing
# There are kentang goreng 150 images for testing
# There are nasi goreng 150 images for testing
# There are pangsit 150 images for testing
# There are pizza 150 images for testing
# There are ramen 150 images for testing
# There are rawon 150 images for testing
# There are rendang 150 images for testing
# There are sate 150 images for testing
# There are soto 150 images for testing

# %%
# Number of images in validation directory
for category in FOOD_CATEGORIES:
    print('There are {} {} images for validation'.format(category, len(os.listdir(os.path.join(VAL_DIR, category)))))
# Out:
# There are bakso 150 images for validation
# There are bibimbap 150 images for validation
# There are burger 150 images for validation
# There are donat 150 images for validation
# There are eskrim 150 images for validation
# There are gado 150 images for validation
# There are kentang goreng 150 images for validation
# There are nasi goreng 150 images for validation
# There are pangsit 150 images for validation
# There are pizza 150 images for validation
# There are ramen 150 images for validation
# There are rawon 150 images for validation
# There are rendang 150 images for validation
# There are sate 150 images for validation
# There are soto 150 images for validation

# %%
print("Sample ramen image:")
plt.imshow(load_img(f"{os.path.join(TRAIN_RAMEN_DIR, os.listdir(TRAIN_RAMEN_DIR)[0])}"))
plt.show()
# Out:
# Sample ramen image:

# %%
handle_base, pixels, FV_SIZE = ("mobilenet_v2", 224, 1280)
MODULE_HANDLE ="https://tfhub.dev/google/tf2-preview/{}/feature_vector/4".format(handle_base)
IMAGE_SIZE = (pixels, pixels)

print("Using {} with input size {} and output dimension {}".format(MODULE_HANDLE, IMAGE_SIZE, FV_SIZE))
# Out:
# Using https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4 with input size (224, 224) and output dimension 1280

# %% [markdown]
# ## **Training and Validation Generator**

# %%
BATCH_SIZE = 64

# %%
  # Datagen
  train_datagen =  tf.keras.preprocessing.image.ImageDataGenerator(
      rescale=1./255,
      shear_range=0.2,
      zoom_range=0.2,
      fill_mode='nearest'
  )

  test_datagen =  ImageDataGenerator(rescale=1./255)
  valid_datagen =  ImageDataGenerator(rescale=1./255)

  # Flow training data generator
  train_generator = train_datagen.flow_from_directory(
      TRAIN_DIR,
      target_size=(224, 224),
      batch_size=BATCH_SIZE,
      shuffle=True,
      class_mode='categorical'
  )

  # Flow validation data generator
  validation_generator = valid_datagen.flow_from_directory(
      VAL_DIR,
      target_size=(224, 224),
      batch_size=BATCH_SIZE,
      shuffle=False,
      class_mode='categorical'
  )

  # Flow test data generator
  test_generator = test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(224, 224),
    batch_size=BATCH_SIZE,
    shuffle=False,
    class_mode='categorical'
)
# Out:
# Found 10500 images belonging to 15 classes.
# Found 2250 images belonging to 15 classes.
# Found 2250 images belonging to 15 classes.

# %% [markdown]
# ## **Building Classifier Model**

# %%
class_names = list(train_generator.class_indices.keys())

# Create a labels.txt file with the class names

with open('labels.txt', 'w') as f:
    f.write('\n'.join(class_names))

# %%
feature_extractor = hub.KerasLayer(
    MODULE_HANDLE,
    input_shape=IMAGE_SIZE + (3,),
    output_shape=[FV_SIZE],
    trainable=False
)

# %%
print("Building model with", MODULE_HANDLE)

model = tf.keras.Sequential([
    feature_extractor,
    tf.keras.layers.Dense(len(class_names), activation='softmax')
])

model.summary()
# Out:
# Building model with https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense (Dense)               (None, 15)                19215
#
# ...
# Total params: 2277199 (8.69 MB)
# Trainable params: 19215 (75.06 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# ## **Train the model using MobileNet v2**

# %%
from keras import callbacks

early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    mode="min",
    patience=3,
    restore_best_weights=True
)

# %%
EPOCHS = 10

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    verbose=1,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/10
# 165/165 [==============================] - 3243s 20s/step - loss: 0.9416 - accuracy: 0.7314 - val_loss: 0.5757 - val_accuracy: 0.8249
# Epoch 2/10
# 165/165 [==============================] - 699s 4s/step - loss: 0.4339 - accuracy: 0.8718 - val_loss: 0.5058 - val_accuracy: 0.8462
# Epoch 3/10
# 165/165 [==============================] - 646s 4s/step - loss: 0.3517 - accuracy: 0.8971 - val_loss: 0.4660 - val_accuracy: 0.8640
# Epoch 4/10
# 165/165 [==============================] - 697s 4s/step - loss: 0.3032 - accuracy: 0.9098 - val_loss: 0.4193 - val_accuracy: 0.8738
# Epoch 5/10
# 165/165 [==============================] - 664s 4s/step - loss: 0.2835 - accuracy: 0.9140 - val_loss: 0.4453 - val_accuracy: 0.8596
# Epoch 6/10
# 165/165 [==============================] - 703s 4s/step - loss: 0.2569 - accuracy: 0.9223 - val_loss: 0.4233 - val_accuracy: 0.8720
# Epoch 7/10
# ...

# %% [markdown]
# ## **Evaluating Model**

# %%
acc=history.history['accuracy']
val_acc=history.history['val_accuracy']
loss=history.history['loss']
val_loss=history.history['val_loss']

epochs=range(len(acc)) # Get number of epochs

# Graph of training and validation accuracy
plt.plot(epochs, acc, 'r', "Training Accuracy")
plt.plot(epochs, val_acc, 'b', "Validation Accuracy")
plt.title('Training and validation accuracy')
plt.show()
print("")

# Graph of training and validation loss
plt.plot(epochs, loss, 'r', "Training Loss")
plt.plot(epochs, val_loss, 'b', "Validation Loss")
plt.show()

# %%
# Evaluate final score on Validation and Testing data

scores = model.evaluate(validation_generator)
scores = model.evaluate(test_generator)
# Out:
# ...
# 36/36 [==============================] - 710s 20s/step - loss: 0.3635 - accuracy: 0.8827

# %% [markdown]
# ## **Saving Model**

# %%
model.save('/content/drive/MyDrive/')

# %%
model.save('/content/drive/MyDrive/Model.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ## **Export The Model**

# %%
RPS_SAVED_MODEL = "rps_saved_model"

# %%
# Export the SavedModel
tf.saved_model.save(model, RPS_SAVED_MODEL)

# %%
# %%bash -s $RPS_SAVED_MODEL
# saved_model_cli show --dir $1 --tag_set serve --signature_def serving_default
# Out:
# The given SavedModel SignatureDef contains the following input(s):
#   inputs['keras_layer_input'] tensor_info:
#       dtype: DT_FLOAT
#       shape: (-1, 224, 224, 3)
#       name: serving_default_keras_layer_input:0
# The given SavedModel SignatureDef contains the following output(s):
#   outputs['dense'] tensor_info:
#       dtype: DT_FLOAT
#       shape: (-1, 15)
#       name: StatefulPartitionedCall:0
# Method name is: tensorflow/serving/predict
# 2024-06-06 06:01:36.523942: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-06 06:01:36.524206: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
loaded = tf.saved_model.load(RPS_SAVED_MODEL)

# %%
print(list(loaded.signatures.keys()))
infer = loaded.signatures["serving_default"]
print(infer.structured_input_signature)
print(infer.structured_outputs)
# Out:
# ['serving_default']
# ((), {'keras_layer_input': TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_layer_input')})
# {'dense': TensorSpec(shape=(None, 15), dtype=tf.float32, name='dense')}

# %% [markdown]
# ## **Convert Model using TFLite's Converter**

# %%
converter = tf.lite.TFLiteConverter.from_saved_model(RPS_SAVED_MODEL)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
# Out:
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.

# %%
tflite_model_file = 'NutriScan_Model.tflite'

with open(tflite_model_file, "wb") as f:
    f.write(tflite_model)

# %%
try:
    from google.colab import files
    files.download('Nutriscan_Model.tflite')
except:
    pass
